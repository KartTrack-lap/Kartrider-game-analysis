# %%
import numpy as np
import pandas as pd
import requests
import json
import urllib.request
import warnings
from tqdm import tqdm
from datetime import datetime
import time
from datetime import timedelta
warnings.filterwarnings(action='ignore')

# %% [markdown]
# - https://developers.nexon.com/kart/api/13/35
# - https://velog.io/@colacan100/KartriderMetaAnalysisProject-Result
# - https://github.com/mschadev/kartrider-open-api-docs

# %% [markdown]
# # 특정 시점 데이터 가지고오기 (단일건)
# - 1초 기준으로도 400건이 넘는다..
# - 이정도면 카트 아직 건재하다..
# - 아마 경기가 안끝나면 포함이 되는듯함

# %% [markdown]
# ## 모든 매치 리스트 조회

# %%
# match_df1
start_date='2021.06.15 06:00:00'
end_date='2021.06.15 06:02:00'
offset='0'
limit='200'
# match_types='ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4e1f1b7e7e78e6c6878'

# match_df1 api get가져오기
api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiMjAwMDA6MTAiLCJhY2NvdW50X2lkIjoiMTg1NDE1NTQyIiwiYXV0aF9pZCI6IjQiLCJleHAiOjE3Mjg2MTA0NjUsImlhdCI6MTY2NTUzODQ2NSwibmJmIjoxNjY1NTM4NDY1LCJzZXJ2aWNlX2lkIjoiNDMwMDExMzkzIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIn0.g9SxU3q_cdWRWsxNiorjegrsKLfgzDuRvaECr13Lt1E'
headers = {'Authorization': api}
_API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}'
# _API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}&match_types={match_types}'
res = requests.get(_API_URL, headers = headers)
data=res.json()

# 데이터프레임으로 가지고 옴
match_df1=pd.DataFrame()
for i in tqdm(range(0, len(data['matches']))):
    tmp=pd.DataFrame(data['matches'][i])
    match_df1=pd.concat([match_df1, tmp])
match_df1.reset_index(inplace=True, drop=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2491.27it/s]

# %%
# match_df2
start_date='2021.06.15 06:00:00'
end_date='2021.06.15 06:02:00'
offset='200'
limit='200'
# match_types='ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4e1f1b7e7e78e6c6878'

# match_df2 api get가져오기
api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiMjAwMDA6MTAiLCJhY2NvdW50X2lkIjoiMTg1NDE1NTQyIiwiYXV0aF9pZCI6IjQiLCJleHAiOjE3Mjg2MTA0NjUsImlhdCI6MTY2NTUzODQ2NSwibmJmIjoxNjY1NTM4NDY1LCJzZXJ2aWNlX2lkIjoiNDMwMDExMzkzIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIn0.g9SxU3q_cdWRWsxNiorjegrsKLfgzDuRvaECr13Lt1E'
headers = {'Authorization': api}
_API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}'
# _API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}&match_types={match_types}'
res = requests.get(_API_URL, headers = headers)
data=res.json()

# 데이터프레임으로 가지고 옴
match_df2=pd.DataFrame()
for i in tqdm(range(0, len(data['matches']))):
    tmp=pd.DataFrame(data['matches'][i])
    match_df2=pd.concat([match_df2, tmp])
match_df2.reset_index(inplace=True, drop=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2504.06it/s]

# %%
# match_df3
start_date='2021.06.15 06:02:00'
end_date='2021.06.15 06:04:00'
offset='0'
limit='200'
# match_types='ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4e1f1b7e7e78e6c6878'

# match_df3 api get가져오기
api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiMjAwMDA6MTAiLCJhY2NvdW50X2lkIjoiMTg1NDE1NTQyIiwiYXV0aF9pZCI6IjQiLCJleHAiOjE3Mjg2MTA0NjUsImlhdCI6MTY2NTUzODQ2NSwibmJmIjoxNjY1NTM4NDY1LCJzZXJ2aWNlX2lkIjoiNDMwMDExMzkzIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIn0.g9SxU3q_cdWRWsxNiorjegrsKLfgzDuRvaECr13Lt1E'
headers = {'Authorization': api}
_API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}'
# _API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}&match_types={match_types}'
res = requests.get(_API_URL, headers = headers)
data=res.json()

# 데이터프레임으로 가지고 옴
match_df3=pd.DataFrame()
for i in tqdm(range(0, len(data['matches']))):
    tmp=pd.DataFrame(data['matches'][i])
    match_df3=pd.concat([match_df3, tmp])
match_df3.reset_index(inplace=True, drop=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2498.99it/s]

# %%
# 400의 데이터 중에서 200건이 겹치는 데이터임
pd.concat([match_df1, match_df2, match_df3])['matches'].value_counts().value_counts()
# Out:
# 2    200
# 1    200
# Name: matches, dtype: int64

# %%
# match_df4
start_date='2021.06.15 06:02:00'
end_date='2021.06.15 06:04:00'
offset='200'
limit='200'
# match_types='ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4e1f1b7e7e78e6c6878'

# match_df4 api get가져오기
api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiMjAwMDA6MTAiLCJhY2NvdW50X2lkIjoiMTg1NDE1NTQyIiwiYXV0aF9pZCI6IjQiLCJleHAiOjE3Mjg2MTA0NjUsImlhdCI6MTY2NTUzODQ2NSwibmJmIjoxNjY1NTM4NDY1LCJzZXJ2aWNlX2lkIjoiNDMwMDExMzkzIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIn0.g9SxU3q_cdWRWsxNiorjegrsKLfgzDuRvaECr13Lt1E'
headers = {'Authorization': api}
_API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}'
# _API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}&match_types={match_types}'
res = requests.get(_API_URL, headers = headers)
data=res.json()

# 데이터프레임으로 가지고 옴
match_df4=pd.DataFrame()
for i in tqdm(range(0, len(data['matches']))):
    tmp=pd.DataFrame(data['matches'][i])
    match_df4=pd.concat([match_df4, tmp])
match_df4.reset_index(inplace=True, drop=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2502.27it/s]

# %%
# match_df3, match_df4는 시간대는 같은데에도 겹치는게 있음
pd.concat([match_df3, match_df4])['matches'].value_counts().value_counts()
# Out:
# 1    150
# 2    125
# Name: matches, dtype: int64

# %% [markdown]
# ## 특정 매치의 상세 정보 조회

# %%
total=pd.DataFrame()
for j in range(len(df_team['teams'])): # 경기 선택 (매치별)
    for k in range(len(df_team['teams'].iloc[j])): # 팀 선택
        tmp=pd.DataFrame()
        for m in range(len(df_team['teams'].iloc[j][k]['players'])): # 플레이어 선택
            tmp=tmp.append(df_team['teams'].iloc[j][k]['players'][m],ignore_index=True)
        tmp['teamId']=df_team['teams'].iloc[j][k]['teamId']
        tmp['matchId']=df_team.iloc[j]['matchId']
        total=pd.concat([total, tmp])

# %%
# match_df1의 matches(matchId)를 가지고 와서 특정 매치 데이터 조회

# match 데이터를 넣어줄 데이터프레임 생성
df_match = pd.DataFrame()

# api를 돌림
for i in tqdm(range(0, len(match_df1))):
    match_id=match_df1['matches'][i]
    api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiMjAwMDA6MTAiLCJhY2NvdW50X2lkIjoiMTg1NDE1NTQyIiwiYXV0aF9pZCI6IjQiLCJleHAiOjE3Mjg2MTA0NjUsImlhdCI6MTY2NTUzODQ2NSwibmJmIjoxNjY1NTM4NDY1LCJzZXJ2aWNlX2lkIjoiNDMwMDExMzkzIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIn0.g9SxU3q_cdWRWsxNiorjegrsKLfgzDuRvaECr13Lt1E'
    headers = {'Authorization': api}
    _API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/{match_id}'
    res = requests.get(_API_URL, headers = headers)
    data=res.json()
    df_match = df_match.append(data,ignore_index=True)

# 개인전과 팀전 분리하여 각각 데이터프레임에 담아줌
df_team=df_match[df_match['players'].isnull()]
df_single=df_match[~df_match['players'].isnull()]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:21<00:00,  9.21it/s]

# %%
# df_single
# 개인전 유저(플레이어) 데이터를 넣어줄 데이터 프레임 생성
df_single_play = pd.DataFrame()
for i in tqdm(range(len(df_single))):
    matchId=df_single.iloc[i]['matchId']
    tmp=pd.DataFrame()
    for j in range(len(df_single.iloc[i]['players'])):
        tmp = tmp.append(df_single.iloc[i]['players'][j],ignore_index=True)
    tmp['matchId']=matchId
    df_single_play=pd.concat([df_single_play, tmp])
col1=df_single_play.columns[:-1].to_list()
col2=df_single_play.columns[-1:].to_list()
new_col=col2+col1
df_single_play=df_single_play[new_col]
df_single_play.reset_index(inplace=True, drop=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 144/144 [00:03<00:00, 45.25it/s]

# %%
# df_team
# 팀전 유저(플레이어) 데이터를 넣어줄 데이터 프레임 생성
df_team_play=pd.DataFrame()
for i in tqdm(range(len(df_team))): # 경기 선택 (매치별)
    matchId=df_team.iloc[i]['matchId']
    tmp=pd.DataFrame()
    for j in range(len(df_team['teams'].iloc[i])): # 팀 선택
        teamId=df_team['teams'].iloc[i][j]['teamId']
        user_tmp=pd.DataFrame()
        for m in range(len(df_team['teams'].iloc[i][j]['players'])): # 플레이어 선택
            user_tmp=user_tmp.append(df_team['teams'].iloc[i][j]['players'][m],ignore_index=True)
        user_tmp['teamId']=teamId
        tmp=tmp.append(user_tmp,ignore_index=True)
    tmp['matchId']=matchId
    df_team_play=df_team_play.append(tmp, ignore_index=True) 

col1=df_team_play.columns[:-2].to_list()
col2=df_team_play.columns[-2:-1].to_list()
col3=df_team_play.columns[-1:].to_list()
new_col=col3+col2+col1
df_team_play=df_team_play[new_col]
df_team_play.reset_index(inplace=True, drop=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 56/56 [00:02<00:00, 19.19it/s]

# %%
df_team_play
# Out:
#               matchId teamId   accountNo characterName  \
# 0    00c50011b763f35b      2  2097418128          나투찐이
# 1    00c50011b763f35b      2   872785805      착한라명4556
# 2    00c50011b763f35b      1  1225338862      gentil페이
# 3    00c50011b763f35b      1   839000750     gentil디지니
# 4    01880013b763ff71      2  1258960203      cocozzon
# ..                ...    ...         ...           ...
# 255  02cf000ab7624f6f      1  1778595717          상큼채이
# 256  02cf000ab7624f6f      1   420042610           척피뚱
# 257  02cf000ab7624f6f      1    84758185        입벌려얼간다
# 258  035d0005b7622487      2  1376318669         정순이래요
# 259  035d0005b7622487      1   621672221         카이누난뎈
#
#                                              character  \
# 0    9ac2f497a2a1484079b1bd3772b2a5557da654d7479d09...
# 1    2ecb10f5e23493727a80a91421d6242a18b131f743676e...
# 2    f6cfb25c76181c9ec7e6e0c308fb91cf08370039eb1c12...
# 3    2ecb10f5e23493727a80a91421d6242a18b131f743676e...
# 4    2ecb10f5e23493727a80a91421d6242a18b131f743676e...
# ..                                                 ...
# 255  041195c896c373b7764e7786fab3006d897fa7326a90fc...
# 256  68739fffd5995d2cefb55e8b65ccc91c4b5edf5ffd7756...
# 257  041195c896c373b7764e7786fab3006d897fa7326a90fc...
# 258  95de437771bb1e094b4f3ef1c1a81574093a01e8d3be03...
# 259  95de437771bb1e094b4f3ef1c1a81574093a01e8d3be03...
#
#                                                   kart license  \
# 0    31d486a8e36b85b83c1d906757c29d10cac9a18db687c3...
# 1    c8d29082c25ca4e06c568d592ec77eb5b4b9403cef96ed...
# 2    9002ba333110adec61a9defea77318127595851df0c7ef...
# 3    751a4dd7b0e66ba60c3feb72191980bfed2eac70689305...
# 4    31d486a8e36b85b83c1d906757c29d10cac9a18db687c3...
# ..                                                 ...     ...
# 255  20589a6ede95e10ad0ad9bcee2b4a442efaea851e3d449...
# 256  0cbfaabef3110eb016a75fba3e00fbe4ae3cafc0a68f5b...
# 257  3c5386a02e14c3623f3763afee5ab0d369d7b42c0ada05...
# 258  6e0bdbfbaf920a569357ef8eee704b678ced1b6015f428...
# 259  07c7e8427a32892762d2420cfccc336230d35c26317b05...
#
#                                                    pet  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 255  c70baab2d17098faa3c9d44388d6e3fb2f5a717631d7da...
# 256  ac4bf7f09a27adb53bd4f5555872db19df0b58e4ed878c...
# 257  c71da2ae214ef9371da937833a0edab58b5ced980b560e...
# 258  fdc7c55113d737db85501abb962b151496dbd1351df310...
# 259  6788e82c3f37ef248fb09963d7df53e99df92a62fee3e1...
#
#                                              flyingPet partsEngine  \
# 0    a87cb96d91a4e0c357c4eaeb7dbc05ef515d183e79a8aa...
# 1    a87cb96d91a4e0c357c4eaeb7dbc05ef515d183e79a8aa...
# 2    a87cb96d91a4e0c357c4eaeb7dbc05ef515d183e79a8aa...
# 3    a87cb96d91a4e0c357c4eaeb7dbc05ef515d183e79a8aa...
# 4    133f42f75b2b64f7d73f4a6a5a92561a5d9a917c964eeb...
# ..                                                 ...         ...
# 255  13e247466d75204e1b3d587abcc11def087f6ffcdfcf79...           0
# 256  a87cb96d91a4e0c357c4eaeb7dbc05ef515d183e79a8aa...           0
# 257  a87cb96d91a4e0c357c4eaeb7dbc05ef515d183e79a8aa...           7
# 258  44338a00eafb0d85851fa471384b28c5c6683ec5e61637...
# 259  8093cc9c4200f45854f78a3fee8592e71cf2c06d0be172...
#
#     partsHandle partsWheel partsKit rankinggrade2 matchRank matchRetired  \
# 0                                               4         4            0
# 1                                               6         1            0
# 2                                               5         3            0
# 3                                               5         2            0
# 4                                               3         1            0
# ..          ...        ...      ...           ...       ...          ...
# 255           0          0        0             4         2            0
# 256           0          0        0             2        99            1
# 257           3         22        8             3        99            1
# 258                                             0         5            0
# 259                                             0        99            1
#
#     matchWin matchTime
# 0          1     84704
# 1          1     79500
# 2          0     82571
# 3          0     80348
# 4          1     65841
# ..       ...       ...
# 255        0    118508
# 256        0
# 257        0
# 258        1    125027
# 259        0
#
# [260 rows x 18 columns]

# %% [markdown]
# # for 문

# %% [markdown]
# ## 모든 매치 리스트 조회
# - 시작 시간과 끝시간 입력받아 모든 매치 조회하는 데이터 프레임 생성
# - 시작지점과 끝지점 모두 분단위를 짝수로 넣어주세요

# %%
api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiMjAwMDA6MTAiLCJhY2NvdW50X2lkIjoiMTg1NDE1NTQyIiwiYXV0aF9pZCI6IjQiLCJleHAiOjE3Mjg2MTA0NjUsImlhdCI6MTY2NTUzODQ2NSwibmJmIjoxNjY1NTM4NDY1LCJzZXJ2aWNlX2lkIjoiNDMwMDExMzkzIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIn0.g9SxU3q_cdWRWsxNiorjegrsKLfgzDuRvaECr13Lt1E'

# %%
def get_matchdata (start, total_end):
    
    start_date=start
    end_date=datetime.strptime(start_date, '%Y.%m.%d %H:%M:%S')+timedelta(minutes=2)
    end_date = datetime.strftime(end_date, '%Y.%m.%d %H:%M:%S')
    limit='200'
    match_df=pd.DataFrame()
    count=0

    # 마지막 start_date가 total_end-2분까지 돌아가도록 설정
    while start_date != total_end :
        
        # 10,000건에 한번씩 5초 슬립
        if count%50==0:
            time.sleep(5)
            
        # offset 0, 200 둘다 돌리도록
        for i in [0, 200]:
            offset=i
            headers = {'Authorization': api}
            _API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}'
            res = requests.get(_API_URL, headers = headers)
            data=res.json()

            for i in tqdm(range(0, len(data['matches']))):
                tmp=pd.DataFrame(data['matches'][i])
                match_df=pd.concat([match_df, tmp])
            
            count=count+1

        # offeset 0, 200 한번씩 돌아간 뒤에 2분 뒤로 다시 돌릴 수 있도록 start와 end 에 2분씩 더해줌
        new_start=datetime.strptime(start_date, '%Y.%m.%d %H:%M:%S')+timedelta(minutes=2)
        start_date = datetime.strftime(new_start, '%Y.%m.%d %H:%M:%S')
        new_end=datetime.strptime(end_date, '%Y.%m.%d %H:%M:%S')+timedelta(minutes=2)
        end_date = datetime.strftime(new_end, '%Y.%m.%d %H:%M:%S')
        
    # api 돌아간 횟수 print(출력)   
    print(count)     
    return match_df

# %%
df=get_matchdata('2021.06.15 06:00:00', '2021.06.15 07:00:00')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 5000.36it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2500.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1662.82it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2499.29it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2447.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2501.37it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 353.88it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2497.20it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1674.64it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2499.59it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1614.81it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1666.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2520.62it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2505.56it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2404.44it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1665.33it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1667.72it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2499.29it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2499.88it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1666.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 5003.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1667.05it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2519.71it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1666.39it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1249.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2497.50it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2565.95it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1665.07it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1665.60it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1633.42it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1250.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1664.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1666.52it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1667.72it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1676.65it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1675.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1666.26it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1667.05it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2500.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2077.21it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1666.79it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1250.24it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1666.13it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1636.99it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1667.05it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1665.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1255.63it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1704.31it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1666.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1665.20it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1663.61it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1667.45it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1664.80it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1666.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1666.13it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1665.20it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1666.92it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1666.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1623.31it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1666.66it/s]
# 60
