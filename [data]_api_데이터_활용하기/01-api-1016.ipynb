# %%
import numpy as np
import pandas as pd
import requests
import json
import urllib.request
import warnings
from tqdm import tqdm
from datetime import datetime
import time
from datetime import timedelta
warnings.filterwarnings(action='ignore')

# %% [markdown]
# - https://developers.nexon.com/kart/api/13/35
# - https://velog.io/@colacan100/KartriderMetaAnalysisProject-Result
# - https://github.com/mschadev/kartrider-open-api-docs

# %% [markdown]
# # api key 입력해주세요

# %%
# 각자의 api key를 복사하여 넣어주세요
api_key='입력'

# %% [markdown]
# # 특정 시점 데이터 가지고오기 (단일건)
# - 1초 기준으로도 400건이 넘는다..
# - 이정도면 카트 아직 건재하다..
# - 아마 경기가 안끝나면 포함이 되는듯함

# %% [markdown]
# ## 모든 매치 리스트 조회

# %%
# match_df1
start_date='2021.06.15 06:00:00'
end_date='2021.06.15 06:02:00'
offset='0'
limit='200'
# match_types='ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4e1f1b7e7e78e6c6878'

# match_df1 api get가져오기
api =api_key
headers = {'Authorization': api}
_API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}'
# _API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}&match_types={match_types}'
res = requests.get(_API_URL, headers = headers)
data=res.json()

# 데이터프레임으로 가지고 옴
match_df1=pd.DataFrame()
for i in tqdm(range(0, len(data['matches']))):
    tmp=pd.DataFrame(data['matches'][i])
    match_df1=pd.concat([match_df1, tmp])
match_df1.reset_index(inplace=True, drop=True)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 738.38it/s]

# %%
# match_df2
start_date='2021.06.15 06:00:00'
end_date='2021.06.15 06:02:00'
offset='200'
limit='200'
# match_types='ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4e1f1b7e7e78e6c6878'

# match_df2 api get가져오기
api =api_key
headers = {'Authorization': api}
_API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}'
# _API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}&match_types={match_types}'
res = requests.get(_API_URL, headers = headers)
data=res.json()

# 데이터프레임으로 가지고 옴
match_df2=pd.DataFrame()
for i in tqdm(range(0, len(data['matches']))):
    tmp=pd.DataFrame(data['matches'][i])
    match_df2=pd.concat([match_df2, tmp])
match_df2.reset_index(inplace=True, drop=True)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 813.13it/s]

# %%
# match_df3
start_date='2021.06.15 06:02:00'
end_date='2021.06.15 06:04:00'
offset='0'
limit='200'
# match_types='ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4e1f1b7e7e78e6c6878'

# match_df3 api get가져오기
api =api_key
headers = {'Authorization': api}
_API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}'
# _API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}&match_types={match_types}'
res = requests.get(_API_URL, headers = headers)
data=res.json()

# 데이터프레임으로 가지고 옴
match_df3=pd.DataFrame()
for i in tqdm(range(0, len(data['matches']))):
    tmp=pd.DataFrame(data['matches'][i])
    match_df3=pd.concat([match_df3, tmp])
match_df3.reset_index(inplace=True, drop=True)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 741.72it/s]

# %%
# match_df4
start_date='2021.06.15 06:02:00'
end_date='2021.06.15 06:04:00'
offset='200'
limit='200'
# match_types='ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4e1f1b7e7e78e6c6878'

# match_df4 api get가져오기
api =api_key
headers = {'Authorization': api}
_API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}'
# _API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}&match_types={match_types}'
res = requests.get(_API_URL, headers = headers)
data=res.json()

# 데이터프레임으로 가지고 옴
match_df4=pd.DataFrame()
for i in tqdm(range(0, len(data['matches']))):
    tmp=pd.DataFrame(data['matches'][i])
    match_df4=pd.concat([match_df4, tmp])
match_df4.reset_index(inplace=True, drop=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 2011.27it/s]

# %%
# match_df3, match_df4는 시간대는 같은데에도 겹치는게 있음
pd.concat([match_df3, match_df4])['matches'].value_counts().value_counts()
# Out:
# 1    150
# 2    125
# Name: matches, dtype: int64

# %% [markdown]
# ## 특정 매치의 상세 정보 조회

# %%
# match_df1의 matches(matchId)를 가지고 와서 특정 매치 데이터 조회

# match 데이터를 넣어줄 데이터프레임 생성
df_match = pd.DataFrame()

# api를 돌림
for i in tqdm(range(0, len(match_df1))):
    match_id=match_df1['matches'][i]
    api =api_key
    headers = {'Authorization': api}
    _API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/{match_id}'
    res = requests.get(_API_URL, headers = headers)
    data=res.json()
    df_match = df_match.append(data,ignore_index=True)

# 개인전과 팀전 분리하여 각각 데이터프레임에 담아줌
df_team=df_match[df_match['players'].isnull()]
df_single=df_match[~df_match['players'].isnull()]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:21<00:00,  9.18it/s]

# %%
# df_single
# 개인전 유저(플레이어) 데이터를 넣어줄 데이터 프레임 생성
df_single_play = pd.DataFrame()
for i in tqdm(range(len(df_single))):
    matchId=df_single.iloc[i]['matchId']
    tmp=pd.DataFrame()
    for j in range(len(df_single.iloc[i]['players'])):
        tmp = tmp.append(df_single.iloc[i]['players'][j],ignore_index=True)
    tmp['matchId']=matchId
    df_single_play=pd.concat([df_single_play, tmp])
col1=df_single_play.columns[:-1].to_list()
col2=df_single_play.columns[-1:].to_list()
new_col=col2+col1
df_single_play=df_single_play[new_col]
df_single_play.reset_index(inplace=True, drop=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 133/133 [00:02<00:00, 48.17it/s]

# %%
# df_team
# 팀전 유저(플레이어) 데이터를 넣어줄 데이터 프레임 생성
df_team_play=pd.DataFrame()
for i in tqdm(range(len(df_team))): # 경기 선택 (매치별)
    matchId=df_team.iloc[i]['matchId']
    tmp=pd.DataFrame()
    for j in range(len(df_team['teams'].iloc[i])): # 팀 선택
        teamId=df_team['teams'].iloc[i][j]['teamId']
        user_tmp=pd.DataFrame()
        for m in range(len(df_team['teams'].iloc[i][j]['players'])): # 플레이어 선택
            user_tmp=user_tmp.append(df_team['teams'].iloc[i][j]['players'][m],ignore_index=True)
        user_tmp['teamId']=teamId
        tmp=tmp.append(user_tmp,ignore_index=True)
    tmp['matchId']=matchId
    df_team_play=df_team_play.append(tmp, ignore_index=True) 

col1=df_team_play.columns[:-2].to_list()
col2=df_team_play.columns[-2:-1].to_list()
col3=df_team_play.columns[-1:].to_list()
new_col=col3+col2+col1
df_team_play=df_team_play[new_col]
df_team_play.reset_index(inplace=True, drop=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 67/67 [00:03<00:00, 17.68it/s]

# %% [markdown]
# # for 문

# %% [markdown]
# ## 모든 매치 리스트 조회
# - 시작 시간과 끝시간 입력받아 모든 매치 조회하는 데이터 프레임 생성
# - 시작지점과 끝지점 모두 분단위를 짝수로 넣어주세요

# %%
def get_matchdata (start, total_end):
    
    start_date=start
    end_date=datetime.strptime(start_date, '%Y.%m.%d %H:%M:%S')+timedelta(minutes=2)
    end_date = datetime.strftime(end_date, '%Y.%m.%d %H:%M:%S')
    limit='200'
    match_df=pd.DataFrame()
    count=0

    # 마지막 start_date가 total_end-2분까지 돌아가도록 설정
    while start_date != total_end :
        
        # 10,000건에 한번씩 5초 슬립
        if count%50==0:
            time.sleep(5)
            
        # offset 0, 200 둘다 돌리도록
        for j in [0, 200]:
            offset=j
            headers = {'Authorization': api}
            _API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}'
            res = requests.get(_API_URL, headers = headers)
            data=res.json()

            for i in tqdm(range(0, len(data['matches']))):
                tmp=pd.DataFrame(data['matches'][i]['matches'], columns=['matches'])
                tmp['matchtype']=data['matches'][i]['matchType']
                tmp['start']=start_date
                tmp['end']=end_date
                match_df=pd.concat([match_df, tmp])
            
            count=count+1

        # offeset 0, 200 한번씩 돌아간 뒤에 2분 뒤로 다시 돌릴 수 있도록 start와 end 에 2분씩 더해줌
        new_start=datetime.strptime(start_date, '%Y.%m.%d %H:%M:%S')+timedelta(minutes=2)
        start_date = datetime.strftime(new_start, '%Y.%m.%d %H:%M:%S')
        new_end=datetime.strptime(end_date, '%Y.%m.%d %H:%M:%S')+timedelta(minutes=2)
        end_date = datetime.strftime(new_end, '%Y.%m.%d %H:%M:%S')
    
    # 중복 제거
    match_df.drop_duplicates(subset='matches', inplace=True)
    
    #reset_index 인덱스 초기화
    match_df.reset_index(inplace=True, drop=True)
    
    # api 돌아간 횟수 print(출력)   
    #print(count)     
    return match_df

# %% [markdown]
# ## 특정 매치 상세 정보 조회
# - 2.1 get_matchdata에서 출력된 match_df를 받아와서 df_single_play, df_team_play 데이터를 추출하는 함수입니다.

# %%
def get_playerdata(match_df):
    # match_df의 matches(matchId)를 가지고 와서 특정 매치 데이터 조회
    # match 데이터를 넣어줄 데이터프레임 생성
    df_match = pd.DataFrame()

    # api를 돌림
    for i in tqdm(range(0, len(match_df))):
        match_id=match_df['matches'][i]
        api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiMjAwMDA6MTAiLCJhY2NvdW50X2lkIjoiMTg1NDE1NTQyIiwiYXV0aF9pZCI6IjQiLCJleHAiOjE3Mjg2MTA0NjUsImlhdCI6MTY2NTUzODQ2NSwibmJmIjoxNjY1NTM4NDY1LCJzZXJ2aWNlX2lkIjoiNDMwMDExMzkzIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIn0.g9SxU3q_cdWRWsxNiorjegrsKLfgzDuRvaECr13Lt1E'
        headers = {'Authorization': api}
        _API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/{match_id}'
        res = requests.get(_API_URL, headers = headers)
        data=res.json()
        df_match = df_match.append(data,ignore_index=True)

    # 개인전과 팀전 분리하여 각각 데이터프레임에 담아줌
    df_team=df_match[df_match['players'].isnull()]
    df_single=df_match[~df_match['players'].isnull()]
    
    # df_single
    # 개인전 유저(플레이어) 데이터를 넣어줄 데이터 프레임 생성
    df_single_play = pd.DataFrame()
    for i in tqdm(range(len(df_single))):
        matchId=df_single.iloc[i]['matchId']
        tmp=pd.DataFrame()
        for j in range(len(df_single.iloc[i]['players'])):
            tmp = tmp.append(df_single.iloc[i]['players'][j],ignore_index=True)
        tmp['matchId']=matchId
        df_single_play=pd.concat([df_single_play, tmp])
    col1=df_single_play.columns[:-1].to_list()
    col2=df_single_play.columns[-1:].to_list()
    new_col=col2+col1
    df_single_play=df_single_play[new_col]
    df_single_play.reset_index(inplace=True, drop=True)
    
    # df_team
    # 팀전 유저(플레이어) 데이터를 넣어줄 데이터 프레임 생성
    df_team_play=pd.DataFrame()
    for i in tqdm(range(len(df_team))): # 경기 선택 (매치별)
        matchId=df_team.iloc[i]['matchId']
        tmp=pd.DataFrame()
        for j in range(len(df_team['teams'].iloc[i])): # 팀 선택
            teamId=df_team['teams'].iloc[i][j]['teamId']
            user_tmp=pd.DataFrame()
            for m in range(len(df_team['teams'].iloc[i][j]['players'])): # 플레이어 선택
                user_tmp=user_tmp.append(df_team['teams'].iloc[i][j]['players'][m],ignore_index=True)
            user_tmp['teamId']=teamId
            tmp=tmp.append(user_tmp,ignore_index=True)
        tmp['matchId']=matchId
        df_team_play=df_team_play.append(tmp, ignore_index=True) 

    col1=df_team_play.columns[:-2].to_list()
    col2=df_team_play.columns[-2:-1].to_list()
    col3=df_team_play.columns[-1:].to_list()
    new_col=col3+col2+col1
    df_team_play=df_team_play[new_col]
    df_team_play.reset_index(inplace=True, drop=True)
    
    return df_single_play, df_team_play

# %%
# 사용예시
df_single_play, df_team_play=get_playerdata(match_df)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 12000/12000 [25:13<00:00,  7.93it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 6860/6860 [04:46<00:00, 23.93it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 5140/5140 [08:25<00:00, 10.16it/s]

# %% [markdown]
# ## 유저 고유 식별자 추출
# - df_single_play, df_team_play 에서 accountNo 받아오기

# %%
def get_accountNo(df_single_play, df_team_play):
    
    #각 데이터의 accountNo 리스트로 받아온 뒤 합치기
    single_list=list(df_single_play['accountNo'])
    team_list=list(df_team_play['accountNo'])
    single_list.extend(team_list)
    
    # 중복 제거
    user_list=set(single_list)
    user_list=list(user_list)
    
    #결과 출력
    return user_list

# %%
# 사용 예시
user_list=get_accountNo(df_single_play, df_team_play)

# %% [markdown]
# ## 유저 고유 식별자로 매치 데이터 조회

# %%
def get_user_match (user_list, start, total_end):
    
    # 1주일 간격으로 400건 (1명 플레이어 당 1주일 최대 400건)
    start_date=start
    end_date=datetime.strptime(start_date, '%Y.%m.%d %H:%M:%S')+timedelta(weeks=1)
    end_date = datetime.strftime(end_date, '%Y.%m.%d %H:%M:%S')
    limit='200'
    match_df=pd.DataFrame()
    count=0
    player_log=pd.DataFrame()
    
    
    # 마지막 start_date가 total_end-2분까지 돌아가도록 설정
    while start_date != total_end :
        
        # 10,000건에 한번씩 5초 슬립
        if count%50==0:
            time.sleep(5)
            
        # offset 0, 200 둘다 돌리도록
        for a in [0, 200]:
            offset=a
            
            for i in tqdm(user_list):
                access_id=i
                headers = {'Authorization': api}
                _API_URL = f'https://api.nexon.co.kr/kart/v1.0/users/{access_id}/matches?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}'
                res = requests.get(_API_URL, headers = headers)
                data=res.json()
                match_tmp=pd.DataFrame()
                player_tmp=pd.DataFrame()
                for j in range(len(data['matches'])):
                    for k in range(len(data['matches'][j])):
                        for m in range(len(data['matches'][j]['matches'])):
                            match_tmp=match_tmp.append(data['matches'][j]['matches'][m],ignore_index=True)
                            player_tmp=df.append(data['matches'][j]['matches'][m]['player'],ignore_index=True)
                            count=count+1
                match_tmp.drop(['player'], axis=1, inplace=True)
                player_tmp.drop(['accountNo', 'characterName'], axis=1, inplace=True)
                player_tmp=df.add_prefix('player_')
                player_log_tmp=pd.concat([match_tmp, player_tmp], axis=1)
                player_log_tmp['nickName']=data['nickName']
                player_log=pd.concat([player_log, player_log_tmp])

        
        new_start=datetime.strptime(start_date, '%Y.%m.%d %H:%M:%S')+timedelta(weeks=1)
        start_date = datetime.strftime(new_start, '%Y.%m.%d %H:%M:%S')
        new_end=datetime.strptime(end_date, '%Y.%m.%d %H:%M:%S')+timedelta(weeks=1)
        end_date = datetime.strftime(new_end, '%Y.%m.%d %H:%M:%S')
    
    #reset_index 인덱스 초기화
    player_log.reset_index(inplace=True, drop=True)
    
    # api 돌아간 횟수 print(출력)   
    #print(count)     
    return player_log

# %%
# 사용 예시
# 두개의 바가 뜨는게 정상
tmp_list=user_list[:5]
player_log=get_user_match (tmp_list, '2021.06.15 00:00:00', '2021.06.22 00:00:00')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:47<00:00,  9.58s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:47<00:00,  9.46s/it]

# %% [markdown]
# # 2021년 6월 19일 (토요일) 기준 하루 접속자 수를 뽑아보자
# - 참고로 2021년 6월 15일 6시 ~ 7시 매치건수 (중복 제거하면) 400건
# - 한번에 출력하는 200건은 진짜 200건이 넘어서 그런게 아니라 무조건 200건이 뽑히게끔 되어 있는 듯 합니다.

# %%
# 중복 제거 하고
a=get_matchdata ('2021.06.19 00:00:00', '2021.06.20 00:00:00')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 494.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 491.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 567.69it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 549.31it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 486.27it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 499.56it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 538.93it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 455.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 544.63it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 486.09it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 458.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 547.76it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 524.03it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 646.57it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 478.14it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 522.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 496.51it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 512.21it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 482.71it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 451.50it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 507.06it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 442.63it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 606.06it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 468.85it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 446.06it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 436.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 517.88it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 522.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 465.05it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 449.27it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 506.97it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 607.55it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 577.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 480.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 461.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 380.62it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 713.49it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 517.93it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 330.82it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 411.42it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 364.02it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 402.20it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 468.64it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 465.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 571.42it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 500.00it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 420.88it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 446.96it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 476.60it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 505.24it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 680.39it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 389.05it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 402.21it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 445.74it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 417.58it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 447.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 712.64it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 471.86it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 468.85it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 416.90it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 433.40it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 445.63it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 491.27it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 449.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 450.01it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 453.61it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 411.53it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 407.27it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 422.00it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 491.16it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 406.15it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 396.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 394.08it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 470.55it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 457.76it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 404.64it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 950.23it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 414.69it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 419.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 416.77it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 471.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 662.88it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 408.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 440.89it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 453.06it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 446.71it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 421.14it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 374.69it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 648.79it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 423.09it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 437.62it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 399.25it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 327.32it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 456.08it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 470.96it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 335.72it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 439.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 345.42it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 449.49it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 435.16it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 356.11it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 339.31it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 359.95it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 323.33it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 422.65it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 354.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 386.09it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 371.26it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 404.25it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 417.58it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 434.21it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 333.57it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 360.74it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 377.01it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 439.12it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 452.96it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 323.13it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 412.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 413.45it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 376.61it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 301.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 390.09it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 422.55it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 388.43it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 344.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 561.08it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 449.69it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 460.37it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 338.81it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 277.15it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 317.05it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 380.33it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 343.13it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 350.86it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 399.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 308.19it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 671.20it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 332.08it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 409.83it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 392.45it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 307.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 343.74it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 361.48it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 343.64it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 400.52it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 445.99it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 349.93it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 341.34it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 359.37it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 421.52it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 339.89it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 292.25it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 239.93it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 314.84it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 311.28it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 327.86it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 304.24it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 385.31it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 345.86it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 295.07it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 344.09it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 277.50it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 571.38it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 415.15it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 341.71it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 677.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 308.40it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 277.51it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 344.01it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 336.95it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 332.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 329.19it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 608.49it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 342.25it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 367.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 335.06it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 288.21it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 354.75it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 313.42it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 857.80it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 435.99it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 299.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 312.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 268.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 286.87it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 288.37it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 322.84it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 312.84it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 273.69it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 306.19it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 291.86it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 284.43it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 316.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 273.01it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 312.38it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 344.72it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 268.89it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 351.15it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 273.91it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 267.19it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 239.52it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 303.19it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 276.14it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 328.38it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 318.81it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 178.73it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 306.13it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 296.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 242.28it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 283.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 320.97it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 260.96it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 318.57it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 253.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 241.56it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 278.24it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 254.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 283.50it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 268.68it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 237.09it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 257.50it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 288.45it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 237.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 287.67it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 253.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 206.64it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 266.33it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 304.04it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 286.54it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 260.62it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 265.15it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 254.31it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 304.60it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 296.12it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 243.92it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 276.80it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 245.96it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 237.76it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 218.13it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 256.38it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 223.97it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 304.53it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 249.33it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 297.79it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 241.57it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 284.13it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 269.78it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 293.96it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 257.90it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 219.48it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 227.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 249.00it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 206.75it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 247.25it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 280.51it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 183.73it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 254.57it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 243.79it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 245.31it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 185.21it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 217.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 261.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 251.96it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 250.08it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 219.21it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 247.34it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 207.39it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 203.82it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 264.63it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 239.82it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 148.07it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 236.57it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 206.57it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 288.82it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 199.08it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 243.08it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 314.96it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 280.77it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 203.14it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 226.63it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 205.00it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 233.05it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 222.64it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 219.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 217.52it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 218.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 134.69it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 226.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 215.95it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 260.84it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 215.76it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 229.72it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 205.81it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 188.79it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 260.91it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 212.14it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 223.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 222.12it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 203.09it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 217.04it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 180.08it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 206.21it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 164.46it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 185.53it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 215.44it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 230.06it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 183.64it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 210.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 202.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 192.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 213.48it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 206.85it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 216.59it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 196.30it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 193.84it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 184.26it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 197.95it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 202.93it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 225.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 261.43it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 184.32it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 247.25it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 171.25it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 181.25it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 189.07it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 173.09it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 189.50it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 252.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 246.21it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 212.25it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 227.44it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 255.54it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 210.26it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 190.69it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 177.64it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 227.27it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 193.95it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 140.48it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 189.39it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 187.07it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 166.55it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 182.45it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 208.93it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 228.23it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 203.32it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 193.27it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 191.96it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 178.93it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 168.19it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 174.41it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 152.22it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 180.90it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 178.06it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 181.95it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 159.68it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 160.55it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 204.38it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 164.92it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 177.68it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 171.61it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 190.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 116.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 159.13it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 161.28it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 186.54it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 184.12it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 141.10it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 171.11it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 164.07it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 156.21it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 172.79it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 171.09it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 197.83it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 173.94it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 193.73it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 182.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 172.56it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 159.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 166.71it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 180.69it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 199.48it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 163.06it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 165.71it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 181.04it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 174.63it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 142.44it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 130.26it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 180.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 173.09it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 159.65it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 162.90it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 162.64it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 147.33it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 213.33it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 154.79it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 143.92it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 163.75it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 130.23it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 142.15it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 168.88it/s]
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 57.65it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 67.87it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 53.41it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 58.62it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 59.59it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 56.23it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 54.43it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 54.12it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 58.91it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.99it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 54.29it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.25it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.76it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 56.62it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.00it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.68it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.79it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.09it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 61.83it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 60.04it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 59.56it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 63.11it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 59.32it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 59.96it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 54.15it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 58.91it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 59.40it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.10it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 64.06it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 50.29it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 62.75it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 57.49it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.85it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 59.78it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 60.22it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 57.92it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 56.73it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 62.39it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 56.20it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 64.42it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 58.49it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 59.80it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 56.24it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.17it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 57.61it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 58.58it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 56.30it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 60.31it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 56.00it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 59.66it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 60.11it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.31it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 56.25it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.81it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 54.68it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 58.75it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.56it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 62.35it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 63.79it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 53.30it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.98it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 53.40it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 60.33it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 61.45it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 57.93it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 59.94it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 53.88it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 62.98it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.59it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 51.03it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 61.42it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 57.64it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 58.88it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 53.04it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.19it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 51.88it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 58.39it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 54.81it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 51.34it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 54.94it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.27it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 60.71it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 50.32it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 56.05it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 60.83it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 49.25it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.64it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.00it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 58.85it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.22it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 54.96it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 61.52it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 53.94it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 60.47it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.46it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.98it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 51.06it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 50.37it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 53.61it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.15it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 57.22it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 63.45it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 53.56it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.05it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 59.10it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.55it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 51.93it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.67it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 50.86it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 56.06it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.56it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.98it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.32it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.24it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.01it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 55.50it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 49.45it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 59.33it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 50.55it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.21it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 49.71it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 60.15it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 53.46it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 50.19it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 50.55it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 53.27it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 52.92it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 54.03it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 50.10it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 59.70it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 49.87it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 51.97it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 56.42it/s]

# %%
len(a)
# Out:
# 1734

# %%
# 사용예시
df_single_play, df_team_play=get_playerdata(a)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1734/1734 [04:16<00:00,  6.75it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1098/1098 [00:50<00:00, 21.53it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 636/636 [01:02<00:00, 10.15it/s]

# %%
# 사용 예시
user_list_210619=get_accountNo(df_single_play, df_team_play)

# %%
len(user_list_210619)
# Out:
# 2441

# %% [markdown]
# ## 결론
# - 매치건수 (중복제거시) 1734건
# - user수 2441명
