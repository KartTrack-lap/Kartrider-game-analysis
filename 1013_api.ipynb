# %%
import pandas as pd

# %%
import requests
import json
import urllib.request

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# - https://developers.nexon.com/kart/api/13/35
# - https://velog.io/@colacan100/KartriderMetaAnalysisProject-Result
# - https://github.com/mschadev/kartrider-open-api-docs

# %% [markdown]
# # 특정 시점 데이터 가지고오기 (단일건)
# - 1초 기준으로도 400건이 넘는다..
# - 이정도면 카트 아직 건재하다..
# - 아마 경기가 안끝나면 포함이 되는듯함

# %% [markdown]
# ## 모든 매치 리스트 조회

# %%
start_date='2021.06.15 06:00:00'
end_date='2021.06.15 06:02:00'
offset='0'
limit='200'
match_types='ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4e1f1b7e7e78e6c6878'

# %%
api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiMjAwMDA6MTAiLCJhY2NvdW50X2lkIjoiMTg1NDE1NTQyIiwiYXV0aF9pZCI6IjQiLCJleHAiOjE3Mjg2MTA0NjUsImlhdCI6MTY2NTUzODQ2NSwibmJmIjoxNjY1NTM4NDY1LCJzZXJ2aWNlX2lkIjoiNDMwMDExMzkzIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIn0.g9SxU3q_cdWRWsxNiorjegrsKLfgzDuRvaECr13Lt1E'
headers = {'Authorization': api}
_API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}&match_types={match_types}'
res = requests.get(_API_URL, headers = headers)
data=res.json()

# %%
match_df1=pd.DataFrame()
for i in tqdm(range(0, len(data['matches']))):
    tmp=pd.DataFrame(data['matches'][i])
    match_df1=pd.concat([match_df1, tmp])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 579.00it/s]

# %%
match_df1['matches'].value_counts(ascending=False)
# Out:
# 033d0001b14b0a76    1
# 03780001b137cba4    1
# 01f10001b1391c21    1
# 024e0001b138e707    1
# 01a80001b138e16a    1
#                    ..
# 00b70001b1413ec5    1
# 01d40001b1410c6a    1
# 03350001b140cc25    1
# 01000001b140a61f    1
# 02420001b1300f2c    1
# Name: matches, Length: 200, dtype: int64

# %%
start_date='2021.06.15 06:00:00'
end_date='2021.06.15 06:02:00'
offset='200'
limit='200'
match_types='ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4e1f1b7e7e78e6c6878'

# %%
api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiMjAwMDA6MTAiLCJhY2NvdW50X2lkIjoiMTg1NDE1NTQyIiwiYXV0aF9pZCI6IjQiLCJleHAiOjE3Mjg2MTA0NjUsImlhdCI6MTY2NTUzODQ2NSwibmJmIjoxNjY1NTM4NDY1LCJzZXJ2aWNlX2lkIjoiNDMwMDExMzkzIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIn0.g9SxU3q_cdWRWsxNiorjegrsKLfgzDuRvaECr13Lt1E'
headers = {'Authorization': api}
_API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}&match_types={match_types}'
res = requests.get(_API_URL, headers = headers)
data=res.json()

# %%
match_df2=pd.DataFrame()
for i in tqdm(range(0, len(data['matches']))):
    tmp=pd.DataFrame(data['matches'][i])
    match_df2=pd.concat([match_df2, tmp])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]

# %%
pd.concat([match_df1,match_df2])['matches'].value_counts(ascending=False)
# Out:
# 02500001af2a6ce4    1
# 00140001af15ced0    1
# 03970001af14ef7d    1
# 007e0001af1506dd    1
# 012f0001af1526aa    1
#                    ..
# 02b90001af1ee9bf    1
# 03f10001af1ef0b4    1
# 02980001af1f189f    1
# 00410001af1f3f03    1
# 00390001af0e8d64    1
# Name: matches, Length: 400, dtype: int64

# %%
len(pd.concat([match_df1,match_df2]))
# Out:
# 400

# %%
pd.concat([match_df1,match_df2])['matches'].value_counts().value_counts()
# Out:
# 1    400
# Name: matches, dtype: int64

# %%
start_date='2021.06.15 06:02:00'
end_date='2021.06.15 06:04:00'
offset='0'
limit='200'
match_types='ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4e1f1b7e7e78e6c6878'

# %%
api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiMjAwMDA6MTAiLCJhY2NvdW50X2lkIjoiMTg1NDE1NTQyIiwiYXV0aF9pZCI6IjQiLCJleHAiOjE3Mjg2MTA0NjUsImlhdCI6MTY2NTUzODQ2NSwibmJmIjoxNjY1NTM4NDY1LCJzZXJ2aWNlX2lkIjoiNDMwMDExMzkzIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIn0.g9SxU3q_cdWRWsxNiorjegrsKLfgzDuRvaECr13Lt1E'
headers = {'Authorization': api}
_API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}&match_types={match_types}'
res = requests.get(_API_URL, headers = headers)
data=res.json()

# %%
match_df3=pd.DataFrame()
for i in tqdm(range(0, len(data['matches']))):
    tmp=pd.DataFrame(data['matches'][i])
    match_df3=pd.concat([match_df3, tmp])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]

# %%
pd.concat([match_df1, match_df2, match_df3])['matches'].value_counts()
# Out:
# 02500001af2a6ce4    2
# 00cf0001af1f7f68    2
# 00410001af1f3f03    2
# 02980001af1f189f    2
# 03f10001af1ef0b4    2
#                    ..
# 00320001af1573fe    1
# 02fe0001af1557ac    1
# 039b0001af153d20    1
# 012f0001af1526aa    1
# 034d0001af2a8f9f    1
# Name: matches, Length: 402, dtype: int64

# %%
pd.concat([match_df1, match_df2, match_df3])['matches'].value_counts().value_counts()
# Out:
# 1    204
# 2    198
# Name: matches, dtype: int64

# %%
# 2~4분에 새로 추가한 200개의 데이터 중에서 198건이 겹치는 데이터임

# %%
start_date='2021.06.15 06:02:00'
end_date='2021.06.15 06:04:00'
offset='200'
limit='200'
match_types='ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4e1f1b7e7e78e6c6878'

# %%
api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiMjAwMDA6MTAiLCJhY2NvdW50X2lkIjoiMTg1NDE1NTQyIiwiYXV0aF9pZCI6IjQiLCJleHAiOjE3Mjg2MTA0NjUsImlhdCI6MTY2NTUzODQ2NSwibmJmIjoxNjY1NTM4NDY1LCJzZXJ2aWNlX2lkIjoiNDMwMDExMzkzIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIn0.g9SxU3q_cdWRWsxNiorjegrsKLfgzDuRvaECr13Lt1E'
headers = {'Authorization': api}
_API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}&match_types={match_types}'
res = requests.get(_API_URL, headers = headers)
data=res.json()

# %%
match_df4=pd.DataFrame()
for i in tqdm(range(0, len(data['matches']))):
    tmp=pd.DataFrame(data['matches'][i])
    match_df4=pd.concat([match_df4, tmp])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1000.79it/s]

# %%
pd.concat([match_df3, match_df4])['matches'].value_counts().value_counts()
# Out:
# 1    384
# 2      8
# Name: matches, dtype: int64

# %%
# 음.. 이것도 겹치는게 있네..

# %%
match_df3.tail(5)
# Out:
#               matches                                          matchType
# 195  022e0001af1a41ea  ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4...
# 196  02b90001af1a3cf8  ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4...
# 197  00460001af1a1f10  ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4...
# 198  02940001af1a1656  ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4...
# 199  00df0001af1a0946  ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4...

# %%
match_df4.head(5)
# Out:
#             matches                                          matchType
# 0  00d20001af1a6550  ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4...
# 1  03f10001af1a471a  ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4...
# 2  039c0001af1a4361  ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4...
# 3  022e0001af1a41ea  ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4...
# 4  02b90001af1a3cf8  ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4...

# %%
# 6시 2분~4분 사이에 플레이 되고 있던 매치는 총 338건인듯..

# %%
# 2분 단위 offeset 0, 200 으로 돌리는게 제일 깔끔할 것 같기는한데
# 다 알아보지 못한다 어차피..

# %%
start_date='2021.06.15 06:02:00'
end_date='2021.06.15 06:04:00'
offset='200'
limit='200'
# match_types='ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4e1f1b7e7e78e6c6878'

# %%
api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiMjAwMDA6MTAiLCJhY2NvdW50X2lkIjoiMTg1NDE1NTQyIiwiYXV0aF9pZCI6IjQiLCJleHAiOjE3Mjg2MTA0NjUsImlhdCI6MTY2NTUzODQ2NSwibmJmIjoxNjY1NTM4NDY1LCJzZXJ2aWNlX2lkIjoiNDMwMDExMzkzIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIn0.g9SxU3q_cdWRWsxNiorjegrsKLfgzDuRvaECr13Lt1E'
headers = {'Authorization': api}
_API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}'
res = requests.get(_API_URL, headers = headers)
data=res.json()

# %%
from tqdm import tqdm

# %%
match_df4=pd.DataFrame()
for i in tqdm(range(0, len(data['matches']))):
    tmp=pd.DataFrame(data['matches'][i])
    match_df4=pd.concat([match_df4, tmp])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 1331.36it/s]

# %%
match_df4
# Out:
#              matches                                          matchType
# 0   00f1000db1470856  7b9f0fd5377c38514dbb78ebe63ac6c3b81009d5a31dd5...
# 1   00ec000bb146f319  7b9f0fd5377c38514dbb78ebe63ac6c3b81009d5a31dd5...
# 2   0397000db146de0a  7b9f0fd5377c38514dbb78ebe63ac6c3b81009d5a31dd5...
# 3   032c000db146d11a  7b9f0fd5377c38514dbb78ebe63ac6c3b81009d5a31dd5...
# 4   012a000bb14697ab  7b9f0fd5377c38514dbb78ebe63ac6c3b81009d5a31dd5...
# ..               ...                                                ...
# 8   0097000ab144d4ec  14e772d195642279cf6c8307125044274db371c1b08fc3...
# 9   02d20005b1449d90  14e772d195642279cf6c8307125044274db371c1b08fc3...
# 10  0180000ab14478c2  14e772d195642279cf6c8307125044274db371c1b08fc3...
# 11  0143000ab1441c0c  14e772d195642279cf6c8307125044274db371c1b08fc3...
# 12  039c000ab143ea1f  14e772d195642279cf6c8307125044274db371c1b08fc3...
#
# [200 rows x 2 columns]

# %% [markdown]
# ## 특정 매치의 상세 정보 조회

# %%
match_df1['matches'][0]
# Out:
# '02500001af2a6ce4'

# %%
len(match_df['matches'])
# Out:
# 200

# %%
match_id=match_df1['matches'][0]

# %%
api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiMjAwMDA6MTAiLCJhY2NvdW50X2lkIjoiMTg1NDE1NTQyIiwiYXV0aF9pZCI6IjQiLCJleHAiOjE3Mjg2MTA0NjUsImlhdCI6MTY2NTUzODQ2NSwibmJmIjoxNjY1NTM4NDY1LCJzZXJ2aWNlX2lkIjoiNDMwMDExMzkzIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIn0.g9SxU3q_cdWRWsxNiorjegrsKLfgzDuRvaECr13Lt1E'
headers = {'Authorization': api}
_API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/{match_id}'
res = requests.get(_API_URL, headers = headers)
data=res.json()

# %%
df_res = pd.DataFrame()
df_res = df_res.append(data,ignore_index=True)
df_user = pd.DataFrame()
# Out:
# C:\Users\JiyoonLee\AppData\Local\Temp\ipykernel_14896\1149777856.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_res = df_res.append(data,ignore_index=True)

# %%
for i in range(len(data['players'])): 
    df_user = df_user.append(data['players'][i],ignore_index=True)
    df_user['matchId']=match_id
    col1=df_user.columns[:-1].to_list()
    col2=df_user.columns[-1:].to_list()
    new_col=col2+col1
    df_user=df_user[new_col]

# %%
match_id=match_df1['matches'][0]
api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiMjAwMDA6MTAiLCJhY2NvdW50X2lkIjoiMTg1NDE1NTQyIiwiYXV0aF9pZCI6IjQiLCJleHAiOjE3Mjg2MTA0NjUsImlhdCI6MTY2NTUzODQ2NSwibmJmIjoxNjY1NTM4NDY1LCJzZXJ2aWNlX2lkIjoiNDMwMDExMzkzIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIn0.g9SxU3q_cdWRWsxNiorjegrsKLfgzDuRvaECr13Lt1E'
headers = {'Authorization': api}
_API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/{match_id}'
res = requests.get(_API_URL, headers = headers)
data=res.json()

df_res = pd.DataFrame()
df_res = df_res.append(data,ignore_index=True)
df_user = pd.DataFrame()

for j in range(len(data['players'])): 
    df_user = df_user.append(data['players'][j],ignore_index=True)
    df_user['matchId']=match_id
    col1=df_user.columns[:-1].to_list()
    col2=df_user.columns[-1:].to_list()
    new_col=col2+col1
    df_user=df_user[new_col]

# %%
df_res = pd.DataFrame()
df_user = pd.DataFrame()

for i in tqdm(range(0, len(match_df1))):
    match_id=match_df1['matches'][i]
    api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiMjAwMDA6MTAiLCJhY2NvdW50X2lkIjoiMTg1NDE1NTQyIiwiYXV0aF9pZCI6IjQiLCJleHAiOjE3Mjg2MTA0NjUsImlhdCI6MTY2NTUzODQ2NSwibmJmIjoxNjY1NTM4NDY1LCJzZXJ2aWNlX2lkIjoiNDMwMDExMzkzIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIn0.g9SxU3q_cdWRWsxNiorjegrsKLfgzDuRvaECr13Lt1E'
    headers = {'Authorization': api}
    _API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/{match_id}'
    res = requests.get(_API_URL, headers = headers)
    data=res.json()
    
    df_res = df_res.append(data,ignore_index=True)
    df_user_tmp = pd.DataFrame()
    for j in range(len(data['players'])): 
        df_user_tmp = df_user_tmp.append(data['players'][j],ignore_index=True)
        
    df_user_tmp['matchId']=match_id
    df_user=df_user.append(df_user_tmp,ignore_index=True)    
    
col1=df_user.columns[:-1].to_list()
col2=df_user.columns[-1:].to_list()
new_col=col2+col1
df_user=df_user[new_col]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:35<00:00,  5.56it/s]

# %%
df_user
# Out:
#               matchId   accountNo characterName  \
# 0    033d0001b14b0a76   637838747          NEA8
# 1    033d0001b14b0a76       51595     TeamAster
# 2    008b0001b14a8ac6  1091317738         OnLy령
# 3    008b0001b14a8ac6   587302792         차마못한말
# 4    008b0001b14a8ac6   386420892          봄설레임
# ..                ...         ...           ...
# 633  01230001b13014ba  1191355816        l눈꽃닥터l
# 634  02420001b1300f2c  1879099361  KaTaRiNaLady
# 635  02420001b1300f2c   319305004           두영전
# 636  02420001b1300f2c   436303646          음주씽씽
# 637  02420001b1300f2c  1023696011          와탕키짱
#
#                                              character  \
# 0    9ac2f497a2a1484079b1bd3772b2a5557da654d7479d09...
# 1    7e0c416c75ac49b3d51b7127a18f5f043867e90b97a759...
# 2    95de437771bb1e094b4f3ef1c1a81574093a01e8d3be03...
# 3    95de437771bb1e094b4f3ef1c1a81574093a01e8d3be03...
# 4    95de437771bb1e094b4f3ef1c1a81574093a01e8d3be03...
# ..                                                 ...
# 633  48357251a360710371aa5c9f0952ea10ab454feae1d53f...
# 634  48357251a360710371aa5c9f0952ea10ab454feae1d53f...
# 635  42c729e64e31aea803e4881432f7b95129ce97535c29e4...
# 636  9db1d0be9ebee32909451e30d6a0dd83fef43f96872ff6...
# 637  95ba69747e53b99e33e1abd17971a791331328ebf80756...
#
#                                                   kart license  \
# 0    e091361f3b01bac4f0f02076327be683f7d6dd9c3fb03e...
# 1    1dce21931147471608aa7cb45f252aeea69608fab139d0...
# 2    1ab581ed45be8cfa723a89f5e182f00f6dd5ac7dd4eac9...
# 3    1d4423326e3d0e8b12d5d01ede67c076b5cc753e43d4b3...
# 4    36e70f3c80ce6452e76e2858c78b4016234b2742e027b7...
# ..                                                 ...     ...
# 633  cdb0f2394c2a841fab17a3ce5662f7582b98075fee1b8d...
# 634  1ab581ed45be8cfa723a89f5e182f00f6dd5ac7dd4eac9...
# 635  1c6cea98387394d270631b39156b4beb34ea252c136523...
# 636  121b935d13a4d8145906140ac6a75093c2dd583098e17d...
# 637  24c9029444bfae084b2269d93491999f54436b03e23ecf...
#
#                                                    pet  \
# 0    9c082493133532566e10d20eadeeb301f795de216c238f...
# 1    b5e59da7e51a056fca10406d710af9898b1f29e4182036...
# 2    7b34fb3da1d2b564672a2ae3938c7ad011f2743e18f088...
# 3    2d4ab5ea02c1bdf313bacd4e68b75a5d5100c2275165c7...
# 4    b5e59da7e51a056fca10406d710af9898b1f29e4182036...
# ..                                                 ...
# 633  717e049bc6fe04cfaffd7e129975a91fef94b1afa45fef...
# 634  d5f191c6a691dc5fffa238811595dfbf5760b980112724...
# 635  bc04969d9c97b4923330ee9917abe82d0528352b116e53...
# 636  73da5e8f7b9be8f96000573a6a9506643bdadfdad029fc...
# 637  73da5e8f7b9be8f96000573a6a9506643bdadfdad029fc...
#
#                                              flyingPet partsEngine  \
# 0    06bb458da7b6e7ab11246d621953627bbaba5945468597...
# 1    44338a00eafb0d85851fa471384b28c5c6683ec5e61637...           0
# 2    44338a00eafb0d85851fa471384b28c5c6683ec5e61637...           1
# 3    44338a00eafb0d85851fa471384b28c5c6683ec5e61637...          11
# 4    5109c1e43283151c0dadbe0fb74f7046d92996768481dc...
# ..                                                 ...         ...
# 633  bc0cb26aec42bbf33f3bba47e9eb930d890df475161666...
# 634  d064fb1098287bc1ddf83798b94585ee317dcd90275b10...          19
# 635  9c5a11f26f80505a588befe6be86a08832ee6408a68567...
# 636  44338a00eafb0d85851fa471384b28c5c6683ec5e61637...          12
# 637  134d30c43f10b461d98952da5555520a29bc1084ae41c4...
#
#     partsHandle partsWheel partsKit rankinggrade2 matchRank matchRetired  \
# 0                                               5         1            0
# 1             0          0        0             5        99            1
# 2             1          2        2             5         1            0
# 3             1          1        2             3         4            0
# 4                                               5         3            0
# ..          ...        ...      ...           ...       ...          ...
# 633                                             3         0            0
# 634                     14                      0        99            1
# 635                                             1        99            1
# 636           1         23        2             0         1            0
# 637                                             1         2            0
#
#     matchWin matchTime
# 0          1     35442
# 1          1
# 2          1     74314
# 3          1     77850
# 4          1     76490
# ..       ...       ...
# 633
# 634        1
# 635        1
# 636        1    117032
# 637        1    118408
#
# [638 rows x 17 columns]

# %%
df_user
# Out:
#               matchId   accountNo characterName  \
# 0    033d0001b14b0a76   637838747          NEA8
# 1    033d0001b14b0a76       51595     TeamAster
# 2    008b0001b14a8ac6  1091317738         OnLy령
# 3    008b0001b14a8ac6   587302792         차마못한말
# 4    008b0001b14a8ac6   386420892          봄설레임
# ..                ...         ...           ...
# 633  01230001b13014ba  1191355816        l눈꽃닥터l
# 634  02420001b1300f2c  1879099361  KaTaRiNaLady
# 635  02420001b1300f2c   319305004           두영전
# 636  02420001b1300f2c   436303646          음주씽씽
# 637  02420001b1300f2c  1023696011          와탕키짱
#
#                                              character  \
# 0    9ac2f497a2a1484079b1bd3772b2a5557da654d7479d09...
# 1    7e0c416c75ac49b3d51b7127a18f5f043867e90b97a759...
# 2    95de437771bb1e094b4f3ef1c1a81574093a01e8d3be03...
# 3    95de437771bb1e094b4f3ef1c1a81574093a01e8d3be03...
# 4    95de437771bb1e094b4f3ef1c1a81574093a01e8d3be03...
# ..                                                 ...
# 633  48357251a360710371aa5c9f0952ea10ab454feae1d53f...
# 634  48357251a360710371aa5c9f0952ea10ab454feae1d53f...
# 635  42c729e64e31aea803e4881432f7b95129ce97535c29e4...
# 636  9db1d0be9ebee32909451e30d6a0dd83fef43f96872ff6...
# 637  95ba69747e53b99e33e1abd17971a791331328ebf80756...
#
#                                                   kart license  \
# 0    e091361f3b01bac4f0f02076327be683f7d6dd9c3fb03e...
# 1    1dce21931147471608aa7cb45f252aeea69608fab139d0...
# 2    1ab581ed45be8cfa723a89f5e182f00f6dd5ac7dd4eac9...
# 3    1d4423326e3d0e8b12d5d01ede67c076b5cc753e43d4b3...
# 4    36e70f3c80ce6452e76e2858c78b4016234b2742e027b7...
# ..                                                 ...     ...
# 633  cdb0f2394c2a841fab17a3ce5662f7582b98075fee1b8d...
# 634  1ab581ed45be8cfa723a89f5e182f00f6dd5ac7dd4eac9...
# 635  1c6cea98387394d270631b39156b4beb34ea252c136523...
# 636  121b935d13a4d8145906140ac6a75093c2dd583098e17d...
# 637  24c9029444bfae084b2269d93491999f54436b03e23ecf...
#
#                                                    pet  \
# 0    9c082493133532566e10d20eadeeb301f795de216c238f...
# 1    b5e59da7e51a056fca10406d710af9898b1f29e4182036...
# 2    7b34fb3da1d2b564672a2ae3938c7ad011f2743e18f088...
# 3    2d4ab5ea02c1bdf313bacd4e68b75a5d5100c2275165c7...
# 4    b5e59da7e51a056fca10406d710af9898b1f29e4182036...
# ..                                                 ...
# 633  717e049bc6fe04cfaffd7e129975a91fef94b1afa45fef...
# 634  d5f191c6a691dc5fffa238811595dfbf5760b980112724...
# 635  bc04969d9c97b4923330ee9917abe82d0528352b116e53...
# 636  73da5e8f7b9be8f96000573a6a9506643bdadfdad029fc...
# 637  73da5e8f7b9be8f96000573a6a9506643bdadfdad029fc...
#
#                                              flyingPet partsEngine  \
# 0    06bb458da7b6e7ab11246d621953627bbaba5945468597...
# 1    44338a00eafb0d85851fa471384b28c5c6683ec5e61637...           0
# 2    44338a00eafb0d85851fa471384b28c5c6683ec5e61637...           1
# 3    44338a00eafb0d85851fa471384b28c5c6683ec5e61637...          11
# 4    5109c1e43283151c0dadbe0fb74f7046d92996768481dc...
# ..                                                 ...         ...
# 633  bc0cb26aec42bbf33f3bba47e9eb930d890df475161666...
# 634  d064fb1098287bc1ddf83798b94585ee317dcd90275b10...          19
# 635  9c5a11f26f80505a588befe6be86a08832ee6408a68567...
# 636  44338a00eafb0d85851fa471384b28c5c6683ec5e61637...          12
# 637  134d30c43f10b461d98952da5555520a29bc1084ae41c4...
#
#     partsHandle partsWheel partsKit rankinggrade2 matchRank matchRetired  \
# 0                                               5         1            0
# 1             0          0        0             5        99            1
# 2             1          2        2             5         1            0
# 3             1          1        2             3         4            0
# 4                                               5         3            0
# ..          ...        ...      ...           ...       ...          ...
# 633                                             3         0            0
# 634                     14                      0        99            1
# 635                                             1        99            1
# 636           1         23        2             0         1            0
# 637                                             1         2            0
#
#     matchWin matchTime
# 0          1     35442
# 1          1
# 2          1     74314
# 3          1     77850
# 4          1     76490
# ..       ...       ...
# 633
# 634        1
# 635        1
# 636        1    117032
# 637        1    118408
#
# [638 rows x 17 columns]

# %%
df_user['matchId'].nunique()
# Out:
# 200

# %%
df_user
# Out:
#               matchId   accountNo characterName  \
# 0    02500001af2a6ce4  1141111812         이병찬오빠
# 1    02500001af2a6ce4  1812585305         손진욱오빠
# 2    01d20001af2a4900  2064189856        케인코르소돌
# 3    01d20001af2a4900  2030183622          엘랑뚜라
# 4    00a30001af2a3190  1175028582          메리리드
# ..                ...         ...           ...
# 640  03970001af1a02be   604313670      Pyoungya
# 641  03970001af1a02be   755289260     WsblEnvyl
# 642  00550001af19f5fc   554282476       ToT3620
# 643  00550001af19f5fc   771813919        아이러브리타
# 644  00550001af19f5fc  1409307742         겨울낙엽k
#
#                                              character  \
# 0    5f7da1b818aefc94cdbc898f3a3d92d02e5786a255a59e...
# 1    eaed96446435f56794a0835a349da0a97e5308e6b29858...
# 2    48357251a360710371aa5c9f0952ea10ab454feae1d53f...
# 3    48357251a360710371aa5c9f0952ea10ab454feae1d53f...
# 4    95de437771bb1e094b4f3ef1c1a81574093a01e8d3be03...
# ..                                                 ...
# 640  95de437771bb1e094b4f3ef1c1a81574093a01e8d3be03...
# 641  95de437771bb1e094b4f3ef1c1a81574093a01e8d3be03...
# 642  4671e909b560c426d32bc83e28c1871a01ca4dd73c7e21...
# 643  48357251a360710371aa5c9f0952ea10ab454feae1d53f...
# 644  d06b646344b0e8933575dc2d411a8b10a4962d0453ba3d...
#
#                                                   kart license  \
# 0    cf9ab44681fb42a095baf0f8950db0b37c82ecbd80885c...
# 1    cf9ab44681fb42a095baf0f8950db0b37c82ecbd80885c...
# 2    e091361f3b01bac4f0f02076327be683f7d6dd9c3fb03e...
# 3    1dce21931147471608aa7cb45f252aeea69608fab139d0...
# 4    4910285b6f3d165f13a41d7f7b4f1c38dc68f7da253c03...
# ..                                                 ...     ...
# 640  1f17ea594f55314c9764df7d8a65eb159e78e72a16cb63...
# 641  1f17ea594f55314c9764df7d8a65eb159e78e72a16cb63...
# 642  1dce21931147471608aa7cb45f252aeea69608fab139d0...
# 643  121b935d13a4d8145906140ac6a75093c2dd583098e17d...
# 644  f7fa5e50c6c2eb79c11bfd7002455d08af519785802f81...
#
#                                                    pet  \
# 0    c2593beb7fab49d1b08b70d3da563e3d1eb3f3e7f347d6...
# 1    eae227dfd9a7c4487d4ec9d1110b4527ae9aeec5c612ed...
# 2    d5f191c6a691dc5fffa238811595dfbf5760b980112724...
# 3    b5e59da7e51a056fca10406d710af9898b1f29e4182036...
# 4    9ecb721ca7670d9c196341ca19ca19fcf7a60b9e8ffe01...
# ..                                                 ...
# 640  7b34fb3da1d2b564672a2ae3938c7ad011f2743e18f088...
# 641  7b34fb3da1d2b564672a2ae3938c7ad011f2743e18f088...
# 642  875fb610637b0d48341b73c0bdb078fa90954c477ea9f2...
# 643  c71da2ae214ef9371da937833a0edab58b5ced980b560e...
# 644  875fb610637b0d48341b73c0bdb078fa90954c477ea9f2...
#
#                                              flyingPet partsEngine  \
# 0    06bb458da7b6e7ab11246d621953627bbaba5945468597...           7
# 1
# 2    ffb9b61e71641f8450a7cbf43804740439c2de2e612ce1...
# 3    44338a00eafb0d85851fa471384b28c5c6683ec5e61637...           2
# 4    a87cb96d91a4e0c357c4eaeb7dbc05ef515d183e79a8aa...           5
# ..                                                 ...         ...
# 640  44338a00eafb0d85851fa471384b28c5c6683ec5e61637...
# 641  44338a00eafb0d85851fa471384b28c5c6683ec5e61637...
# 642  a87cb96d91a4e0c357c4eaeb7dbc05ef515d183e79a8aa...           0
# 643  fbf9b4761e26803824583eb8831141750b16561c38c869...
# 644  eb775d51bc66967c6c9ae3cb4cfa1a5be39980b1fa7ec0...
#
#     partsHandle partsWheel partsKit rankinggrade2 matchRank matchRetired  \
# 0             3         18       14             0        99            1
# 1                                               0        99            1
# 2                                               0        99            1
# 3             2          2        2             3         0            0
# 4             1         22        3             5         1            0
# ..          ...        ...      ...           ...       ...          ...
# 640                                             5         2            0
# 641                                             0         1            0
# 642           0          0        0             1        99            1
# 643                                             3         1            0
# 644                                             1        99            1
#
#     matchWin matchTime
# 0          0
# 1          0
# 2          0
# 3
# 4          1    131843
# ..       ...       ...
# 640        1     87129
# 641        1     84016
# 642        1
# 643        1    103213
# 644        1
#
# [645 rows x 17 columns]

# %% [markdown]
# # for 문 돌리기
# - 여기 아래는 수정중입니다. (2022, 10, 13 10시 44분)

# %%
api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiMjAwMDA6MTAiLCJhY2NvdW50X2lkIjoiMTg1NDE1NTQyIiwiYXV0aF9pZCI6IjQiLCJleHAiOjE3Mjg2MTA0NjUsImlhdCI6MTY2NTUzODQ2NSwibmJmIjoxNjY1NTM4NDY1LCJzZXJ2aWNlX2lkIjoiNDMwMDExMzkzIiwidG9rZW5fdHlwZSI6IkFjY2Vzc1Rva2VuIn0.g9SxU3q_cdWRWsxNiorjegrsKLfgzDuRvaECr13Lt1E'

# %%
for i in [0, 200]:
    print(i)
# Out:
# 0
# 200

# %%
def (start, end)
start_date=start
end_date=end
for i in [0, 200]:
offset='0'
limit='200'
match_types='ee2426e23fa56f7a695084e1fc07fe6bb03a0b3b0c71c4e1f1b7e7e78e6c6878'

headers = {'Authorization': api}
_API_URL = f'https://api.nexon.co.kr/kart/v1.0/matches/all?start_date={start_date}&end_date={end_date}&offset={offset}&limit={limit}&match_types={match_types}'
res = requests.get(_API_URL, headers = headers)
data=res.json()

match_df1=pd.DataFrame()
for i in tqdm(range(0, len(data['matches']))):
    tmp=pd.DataFrame(data['matches'][i])
    match_df1=pd.concat([match_df1, tmp])
